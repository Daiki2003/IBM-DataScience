# %%
import pandas as pd

# %%
df = pd.read_csv("KNN_Project_Data.unknown")

# %%
df
# Out:
#      Gender  Age  Salary  Purchase Iphone
# 0      Male   19   19000                0
# 1      Male   35   20000                0
# 2    Female   26   43000                0
# 3    Female   27   57000                0
# 4      Male   19   76000                0
# ..      ...  ...     ...              ...
# 395  Female   46   41000                1
# 396    Male   51   23000                1
# 397  Female   50   20000                1
# 398    Male   36   33000                0
# 399  Female   49   36000                1
#
# [400 rows x 4 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue = "TARGET CLASS", palette = "coolwarm")

# %%
from sklearn.preprocessing import StandardScaler

# %%
SC = StandardScaler()

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop("TARGET CLASS", axis = 1)

# %%
X = SC.fit_transform(X)

# %%
Y = df["TARGET CLASS"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,train_size = 0.2, random_state = 42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 20)

# %%
knn.fit(X_train,Y_train)

# %%
Y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy_score(Y_pred, Y_test)

# %%
print(classification_report(Y_pred, Y_test))

# %%
import numpy as np

# %%
error = []
for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(X_train,Y_train)
    Y_pred = knn.predict(X_test)
    error.append(np.mean(Y_pred != Y_test))

# %%
error

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize = (10,6))
plt.plot(range(1,40), error, color = "blue", linestyle = "dashed", marker = "o", markerfacecolor = "red", markersize = 10)
plt.title("Error Rate VS K Value")
plt.xlabel("K")
plt.ylabel("Error Rate")

# %%
knn = KNeighborsClassifier(n_neighbors = 33)
knn.fit(X_train,Y_train)
Y_pred = knn.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14076\2758676620.py in <module>
# ----> 1 knn = KNeighborsClassifier(n_neighbors = 33)
#       2 knn.fit(X_train,Y_train)
#       3 Y_pred = knn.predict(X_test)
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
accuracy_score(Y_pred, Y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14076\822466048.py in <module>
# ----> 1 accuracy_score(Y_pred, Y_test)
#
# NameError: name 'accuracy_score' is not defined

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = []
for ks in range(1,30):
    model = KNeighborsClassifier(n_neighbors = ks)
    score = cross_val_score(model, X_train, Y_train, cv = 5, scoring = "accuracy")
    scores.append(np.mean(score))
    
best_k = scores.index(max(scores))
print(f"The best k is {best_k}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14076\586319914.py in <module>
#       1 scores = []
#       2 for ks in range(1,30):
# ----> 3     model = KNeighborsClassifier(n_neighbors = ks)
#       4     score = cross_val_score(model, X_train, Y_train, cv = 5, scoring = "accuracy")
#       5     scores.append(np.mean(score))
#
# NameError: name 'KNeighborsClassifier' is not defined
